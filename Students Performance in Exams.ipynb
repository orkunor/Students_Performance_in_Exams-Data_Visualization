# %%
########Students Performance in Exams

#######Students give us data such as math, reading, writing in this dataset.

######The data have students' ethnic origin, education level, gender, and other factors etc.

#####Now, according to this information given to us, we will try to predict where students are successful.

####The column called lunch shows the participation of schools in the meal program in 2 types, standard or free.

###The gender column tells us about the gender of the student.

##race/ethnicity : in this background, the student's ethnicity gives information about their race. There are 5 different origins.

#parents have education level 3 types this is

# %%
#We import the necessary libraries

import numpy as np
import pandas as pd 

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("darkgrid")

# %%
df=pd.read_csv("StudentsPerformance.csv")

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.shape
# We have 1000 rows and 8 columns
# Out:
# (1000, 8)

# %%
df.describe().T
#count 
#mean 
#std 
#min 
#max
# Out:
#                 count    mean        std   min    25%   50%   75%    max
# math score     1000.0  66.089  15.163080   0.0  57.00  66.0  77.0  100.0
# reading score  1000.0  69.169  14.600192  17.0  59.00  70.0  79.0  100.0
# writing score  1000.0  68.054  15.195657  10.0  57.75  69.0  79.0  100.0

# %%
df.isnull()
# Out:
#      gender  race/ethnicity  parental level of education  lunch  \
# 0     False           False                        False  False
# 1     False           False                        False  False
# 2     False           False                        False  False
# 3     False           False                        False  False
# 4     False           False                        False  False
# ..      ...             ...                          ...    ...
# 995   False           False                        False  False
# 996   False           False                        False  False
# 997   False           False                        False  False
# 998   False           False                        False  False
# 999   False           False                        False  False
#
#      test preparation course  math score  reading score  writing score
# 0                      False       False          False          False
# ...

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
#let's graph a column using math column
p=sns.countplot(x="math score",data=df,palette="muted")
plt.xticks(rotation=90)
plt.show()

# %%
#Let's set some criteria and see how many students are successful according to the criteria we have determined.
passmark=50
df["Math_PassStatus"]=np.where(df["math score"]<passmark,"F","P")# We added a column called Math_PassStatus
#We call this column we add "take the math score" for us.
#Let values be False and Positive if greater.
df.Math_PassStatus.value_counts()
# Out:
# P    865
# F    135
# Name: Math_PassStatus, dtype: int64

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
#Now I will look at the success of the students according to the educational status of the parents.
p=sns.countplot(x="parental level of education",hue="Math_PassStatus",data=df,palette="bright") #hue ile karşılaştırma yaptırıyoruz
plt.xticks(rotation=90)
plt.show()

# %%
p=sns.countplot(x="reading score",data=df,palette="bright") 
plt.xticks(rotation=90)
plt.show()

# %%
passmark=50
df["Reading_PassStatus"]=np.where(df["reading score"]<passmark,"F","P")
df.Reading_PassStatus.value_counts()
# Out:
# P    910
# F     90
# Name: Reading_PassStatus, dtype: int64

# %%
p=sns.countplot(x="parental level of education",hue="Reading_PassStatus",data=df,palette="bright") #hue ile karşılaştırma yaptırıyoruz
plt.xticks(rotation=90)
plt.show()

# %%
p=sns.countplot(x="writing score",data=df,palette="bright") 
plt.xticks(rotation=90)
plt.show()

# %%
df["Writing_PassStatus"]=np.where(df["writing score"]<passmark,"F","P")
df.Writing_PassStatus.value_counts()
# Out:
# P    886
# F    114
# Name: Writing_PassStatus, dtype: int64

# %%
p=sns.countplot(x="parental level of education",hue="Writing_PassStatus",data=df,palette="bright") 
# we make comparisons with hue
plt.xticks(rotation=90)
plt.show()

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
# Let's create a new column in the form of overallpassstatus and examine whether it has passed or not.
# This column will look at whether a student has failed all of the courses.
df["Overall_PassStatus"] = df.apply(lambda x: "F" if x["Math_PassStatus"]== 'F' 
                                     or x["Reading_PassStatus"]== 'F' or x["Writing_PassStatus"]== 'F'
                                    else 'P' , axis =1)
df.Overall_PassStatus.value_counts() #Now we're looking at the number of them.
# if fully successful 812
# Out:
# P    812
# F    188
# Name: Overall_PassStatus, dtype: int64

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
p=sns.countplot(x="parental level of education",hue="Overall_PassStatus",data=df,palette="bright") 
# we compare it to hue
plt.xticks(rotation=90)
plt.show()

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#   Math_PassStatus Reading_PassStatus Writing_PassStatus Overall_PassStatus
# 0               P                  P                  P                  P
# ...

# %%
# Now let's find the average of 3 grades
df["Total Max"] = df["math score"]+df["reading score"] + df["writing score"]

# %%
df["Percentage"] = df["Total Max"]/3

# %%
df["Percentage"] = df["Total Max"]/3

# %%
p=sns.countplot(x="Percentage",data=df,palette="muted") 
plt.xticks(rotation=90)
plt.show()

# %%
def GetGrade(Percentage,Overall_PassStatus):
    if (Overall_PassStatus == 'F'):
        return 'F'
    if (Percentage >= 80):
        return 'A'
    if (Percentage >= 70):
        return 'B'
    if (Percentage >= 60):
        return 'c'
    if (Percentage >= 50):
        return 'D'
    if (Percentage >= 40):
        return 'E'
    else:
        return 'F'
df['Grade'] = df.apply(lambda x : GetGrade(x['Percentage'],x['Overall_PassStatus']),axis=1)

df.Grade.value_counts()
# Out:
# B    261
# c    255
# A    198
# F    188
# D     98
# Name: Grade, dtype: int64

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#   Math_PassStatus Reading_PassStatus Writing_PassStatus Overall_PassStatus  \
# ...

# %%
sns.countplot(x="Grade",data=df,order=["A","B","C","D","E","F"]) 
plt.show()

# %%
p=sns.countplot(x="parental level of education",hue="Grade",data=df,palette="bright") #hue ile karşılaştırma yaptırıyoruz
plt.xticks(rotation=90)
plt.show()

# %%
# reach the numbers of boys and girls, let's visualize them too
df_gender=df["gender"]
female_count = df_gender.value_counts()["female"]
male_count = df_gender.value_counts()["male"]

# %%
female_count , male_count
# Out:
# (518, 482)

# %%
female_ratio = female_count/(male_count+female_count) * 100
male_ratio = male_count/(female_count+male_count) * 100

# %%
print("Number of Girls Ratio : ",int(female_ratio))
print("Number of men Ratio :",int(male_ratio))
# Out:
# Number of Girls Ratio :  51
# Number of men Ratio : 48

# %%
labels = ["Girl","Man"]
sizes=[female_ratio,male_ratio]
colors=["pink","lightblue"]
plt.pie(sizes,labels=labels,colors=colors,autopct="%1.1f%%",startangle=90)

plt.axis("equal")
plt.title("Girl-Male Ratios")
plt.show()

# %%
# now let's just see the girls' success in math class
df_female=df[df["gender"]=="female"]
df_male=df[df["gender"]=="male"]
female_math_mean=df_female["math score"].mean()
male_math_mean=df_male["math score"].mean()

female_to_male_math_ratio = female_math_mean/male_math_mean

print("Ratio of girls to boys : ",female_to_male_math_ratio)
# Out:
# Ratio of girls to boys :  0.9258672573189434

# %%
# now let's show the averages on the graph 
# Let's create a bar chart
labels=["Girls","men"]
values=[female_math_mean,male_math_mean]
colors=["pink","lightblue"]
plt.bar(labels,values,color=colors) # here we create our graph  

plt.axhline(y=male_math_mean,color="gray",linestyle="--") # we create a horizontal line to see it exactly 
plt.text(-0,male_math_mean,"Average(Men)",ha="right")

plt.axhline(y=female_math_mean,color="gray",linestyle="--")
plt.text(1.1,female_math_mean,"Average(Girls)",ha="left")
plt.text(-0.8,female_math_mean*1.05,"Oran: {:.2f}".format(female_to_male_math_ratio),ha="center")

plt.xlabel("cinsiyet")
plt.ylabel("mat.notu")
plt.title("Kızların Mat Dersindeki Başarısının Erkeklere Oranı")
# As can be seen, the average for men is generally higher
# Out:
# Text(0.5, 1.0, 'Kızların Mat Dersindeki Başarısının Erkeklere Oranı')

# %%
# Now let's calculate the ratio of the education level of the families to the mathematics or other subjects.
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#   Math_PassStatus Reading_PassStatus Writing_PassStatus Overall_PassStatus  \
# ...

# %%
parental_edu_counts=df["parental level of education"].value_counts() # we got the number

# now let's convert the education levels into a list

parental_edu_levels = parental_edu_counts.index.tolist()

math_scores=[]

for level in parental_edu_levels:
    math_scores.append(df[df["parental level of education"]==level]["math score"].mean())
    
plt.bar(parental_edu_levels,math_scores)

plt.xlabel("family education level")
plt.ylabel("math average")
plt.title("family education math relationship")
plt.xticks(rotation=90)
plt.show()

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#   Math_PassStatus Reading_PassStatus Writing_PassStatus Overall_PassStatus  \
# ...

# %%
parental_edu_counts=df["parental level of education"].value_counts() 

parental_edu_levels = parental_edu_counts.index.tolist()

reading_scores=[]

for level in parental_edu_levels:
    reading_scores.append(df[df["parental level of education"]==level]["reading score"].mean())
    
plt.bar(parental_edu_levels,math_scores)

plt.xlabel("family education level")
plt.ylabel("reading skill")
plt.title("family education relationship")
plt.xticks(rotation=90)
plt.show()

# %%
# The lunch column doesn't have much of an effect, but on the notes that will have an effect, as ethnicity has different variants.
# Let's examine the effect of ethnicity on mathematics 
ethnic=df.groupby("race/ethnicity")["math score"].mean().reset_index()
plt.bar(ethnic["race/ethnicity"],ethnic["math score"])
plt.title("Mathematics grade by ethnicity")
plt.xlabel("Ethnicity")
plt.ylabel("Maths")
plt.show()

# %%
# Let's evaluate math grades by grouping them according to ethnicity and parental education levels.

ethnic=df.groupby(["race/ethnicity","parental level of education"])["math score"].mean().reset_index()
sns.catplot(x="parental level of education",y="math score",hue="race/ethnicity",kind="bar",data=ethnic,height=6,aspect=1.5)
# We set the aspect ratio of the aspect figure!!!
plt.title("Mathematics grade by ethnicity")
plt.xlabel("Ethnicity")
plt.ylabel("Math")
plt.show()

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#   Math_PassStatus Reading_PassStatus Writing_PassStatus Overall_PassStatus  \
# ...

# %%
group=df.groupby("test preparation course")["math score"].mean()

plt.bar(group.index,group.values)

plt.title("Mathematics relation according to the status of completing the test course")
plt.xlabel("Course")
plt.ylabel("Maths")
plt.show()
